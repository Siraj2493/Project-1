# %%
import requests
import pandas as pd

# %%
# import path for imports
import sys
import os
import_path = os.path.join('c:', os.sep, "Users", "shane", "OneDrive", "MyDocuments", "AppDev", "my_imports")
sys.path.insert(1, import_path)

# %%
from config_keys import ncdc

# %%
#base_url = "www.ncdc.noaa.gov/cdo-web/api/v2/stations"
base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"
token = ncdc,
# https://www.ncdc.noaa.gov/cdo-web/api/v2/data?
params = {
    'locationid' : 'ZIP:28801',
    'startdate' : '2010-05-01',
    'enddate' : '2010-05-01',
    'datasetid' : 'GHCND'
}


#https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:28801&startdate=2010-05-01&enddate=2010-05-01

# %%
results = requests.get(base_url, params=params, headers={'token':ncdc})

# %%
results.json()
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 8, 'limit': 25}},
#  'results': [{'date': '2010-05-01T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1NCBC0005',
#    'attributes': ',,N,',
#    'value': 0},
#   {'date': '2010-05-01T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:US1NCBC0005',
#    'attributes': ',,N,',
#    'value': 0},
#   {'date': '2010-05-01T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:USW00013872',
#    'attributes': ',,0,2400',
#    'value': 3},
#   {'date': '2010-05-01T00:00:00',
#    'datatype': 'SNOW',
#    'station': 'GHCND:USW00013872',
#    'attributes': ',,0,',
#    'value': 0},
#   {'date': '2010-05-01T00:00:00',
#    'datatype': 'SNWD',
#    'station': 'GHCND:USW00013872',
#    'attributes': ',,0,',
#    'value': 0},
#   {'date': '2010-05-01T00:00:00',
#    'datatype': 'TMAX',
#    'station': 'GHCND:USW00013872',
#    'attributes': ',,0,2400',
#    'value': 267},
#   {'date': '2010-05-01T00:00:00',
# ...

# %%
#get stations in a zip code
base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/stations"
#base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"
token = ncdc
# https://www.ncdc.noaa.gov/cdo-web/api/v2/data?
params = {
    'locationid' : 'ZIP:30062',
    'startdate' : '2010-01-01',
    'enddate' : '2010-01-01',
}

# %%
results = requests.get(base_url, params=params, headers={'token':token})

# %%
results.json()
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 6, 'limit': 25}},
#  'results': [{'elevation': 196.6,
#    'mindate': '1995-05-04',
#    'maxdate': '2020-01-28',
#    'latitude': 33.17194,
#    'name': 'BIRMINGHAM, AL US',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:KBMX',
#    'elevationUnit': 'METERS',
#    'longitude': -86.76972},
#   {'elevation': 261.5,
#    'mindate': '1994-11-09',
#    'maxdate': '2020-01-28',
#    'latitude': 33.36333,
#    'name': 'ATLANTA, GA US',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:KFFC',
#    'elevationUnit': 'METERS',
#    'longitude': -84.56583},
#   {'elevation': 286.5,
#    'mindate': '1995-04-19',
#    'maxdate': '2020-01-28',
#    'latitude': 34.88306,
#    'name': 'GREER, SC US',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:KGSP',
#    'elevationUnit': 'METERS',
#    'longitude': -82.22028},
#   {'elevation': 536.4,
#    'mindate': '1997-07-05',
#    'maxdate': '2020-01-28',
#    'latitude': 34.93056,
# ...

# %%
# https://gist.github.com/erichurst/7882666
# zip code data
zip_codes = pd.read_csv('ziplatlng.csv')

# %%
zip_codes
# Out:
#          ZIP        LAT         LNG
# 0        601  18.180555  -66.749961
# 1        602  18.361945  -67.175597
# 2        603  18.455183  -67.119887
# 3        606  18.158345  -66.932911
# 4        610  18.295366  -67.125135
# ...      ...        ...         ...
# 33139  99923  56.002315 -130.041026
# 33140  99925  55.550204 -132.945933
# 33141  99926  55.138352 -131.470424
# 33142  99927  56.239062 -133.457924
# 33143  99929  56.370751 -131.693301
#
# [33144 rows x 3 columns]

# %%
#get stations in a zip code
base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/locations"
#base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"
token = ncdc
# https://www.ncdc.noaa.gov/cdo-web/api/v2/data?
params = {
    'locationcategoryid' : 'ST',
    'startdate' : '2000-01-01',
    'enddate' : '2010-01-01',
    'datasetid' : 'GSOM',
    'limit' : 51
}

results = requests.get(base_url, params=params, headers={'token':token})
results.json()
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 51, 'limit': 51}},
#  'results': [{'mindate': '1888-02-01',
#    'maxdate': '2019-12-01',
#    'name': 'Alabama',
#    'datacoverage': 1,
#    'id': 'FIPS:01'},
#   {'mindate': '1893-10-01',
#    'maxdate': '2019-12-01',
#    'name': 'Alaska',
#    'datacoverage': 1,
#    'id': 'FIPS:02'},
#   {'mindate': '1867-08-01',
#    'maxdate': '2019-12-01',
#    'name': 'Arizona',
#    'datacoverage': 1,
#    'id': 'FIPS:04'},
#   {'mindate': '1871-07-01',
#    'maxdate': '2019-12-01',
#    'name': 'Arkansas',
#    'datacoverage': 1,
#    'id': 'FIPS:05'},
#   {'mindate': '1850-10-01',
#    'maxdate': '2019-12-01',
#    'name': 'California',
#    'datacoverage': 1,
#    'id': 'FIPS:06'},
#   {'mindate': '1852-10-01',
#    'maxdate': '2019-12-01',
#    'name': 'Colorado',
#    'datacoverage': 1,
#    'id': 'FIPS:08'},
#   {'mindate': '1884-11-01',
#    'maxdate': '2019-12-01',
#    'name': 'Connecticut',
#    'datacoverage': 1,
# ...

# %%
weather_states = pd.DataFrame(results.json()['results'])
weather_states
# Out:
#        mindate     maxdate                  name  datacoverage       id
# 0   1888-02-01  2019-12-01               Alabama             1  FIPS:01
# 1   1893-10-01  2019-12-01                Alaska             1  FIPS:02
# 2   1867-08-01  2019-12-01               Arizona             1  FIPS:04
# 3   1871-07-01  2019-12-01              Arkansas             1  FIPS:05
# 4   1850-10-01  2019-12-01            California             1  FIPS:06
# 5   1852-10-01  2019-12-01              Colorado             1  FIPS:08
# 6   1884-11-01  2019-12-01           Connecticut             1  FIPS:09
# 7   1893-01-01  2019-12-01              Delaware             1  FIPS:10
# 8   1870-11-01  2019-12-01  District of Columbia             1  FIPS:11
# 9   1871-10-01  2019-12-01               Florida             1  FIPS:12
# 10  1849-01-01  2019-12-01               Georgia             1  FIPS:13
# 11  1905-01-01  2019-12-01                Hawaii             1  FIPS:15
# ...

# %%
#get stations in a zip code
base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data?"
token = ncdc

params = {
    'datasetid' : 'GSOM',
    'locationid' : 'FIPS:13',
    'units' : 'standard',
    'startdate' : '2019-01-01',
    'enddate' : '2019-12-01',
    'datatypeid' : 'TAVG',
    #'stationid' : 'GHCND:USC00090006'
}

#//www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GSOM&stationid=GHCND:USC00010008&units=standard&startdate=2010-05-01&enddate=2010-05-31


results = requests.get(base_url, params=params, headers={'token':token})

# %%
results
# Out:
# <Response [200]>

# %%
results.json()
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 1308, 'limit': 25}},
#  'results': [{'date': '2019-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090140',
#    'attributes': ',7',
#    'value': 50.0},
#   {'date': '2019-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090236',
#    'attributes': ',7',
#    'value': 42.0},
#   {'date': '2019-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090311',
#    'attributes': ',7',
#    'value': 45.6},
#   {'date': '2019-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090969',
#    'attributes': ',7',
#    'value': 37.4},
#   {'date': '2019-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00091266',
#    'attributes': ',7',
#    'value': 51.1},
#   {'date': '2019-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00091340',
#    'attributes': '2,H',
#    'value': 54.3},
#   {'date': '2019-01-01T00:00:00',
# ...

# %%
print(results.req)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-b56cf367a409> in <module>
# ----> 1 print(results.req)
#
# AttributeError: 'Response' object has no attribute 'req'

# %%
//www.ncdc.noaa.gov/cdo-web/api/v2/stations?datatypeid=EMNT&datatypeid=EMXT&datatypeid=HTMN
//www.ncdc.noaa.gov/cdo-web/api/v2/stations?locationid=FIPS:37

# %%
base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/stations?"
token = ncdc

params = {
    #'datasetid' : 'GSOM',
    #'datatypeid' : 'TAVG',
    #'locationid' : 'ST:FIPS:13',
    #'units' : 'standard',
    'startdate' : '2000-01-01',
    'locationid' : 'FIPS:37',
    'enddate' : '2010-12-01',
    'datatypeid' : 'ALL'
}

#//www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GSOM&stationid=GHCND:USC00010008&units=standard&startdate=2010-05-01&enddate=2010-05-31


station_results = requests.get(base_url, params=params, headers={'token':token})

# %%
station_results.json()
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 12, 'limit': 25}},
#  'results': [{'elevation': 34.1,
#    'mindate': '1995-01-01',
#    'maxdate': '2020-01-28',
#    'latitude': 36.98389,
#    'name': 'NORFOLK RICH, VA US',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:KAKQ',
#    'elevationUnit': 'METERS',
#    'longitude': -77.0075},
#   {'elevation': 70.4,
#    'mindate': '1994-06-27',
#    'maxdate': '2020-01-28',
#    'latitude': 33.94861,
#    'name': 'COLUMBIA, SC US',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:KCAE',
#    'elevationUnit': 'METERS',
#    'longitude': -81.11861},
#   {'elevation': 874.2,
#    'mindate': '1995-02-13',
#    'maxdate': '2020-01-28',
#    'latitude': 37.02417,
#    'name': 'ROANOKE, VA US',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:KFCX',
#    'elevationUnit': 'METERS',
#    'longitude': -80.27417},
#   {'elevation': 261.5,
#    'mindate': '1994-11-09',
#    'maxdate': '2020-01-28',
#    'latitude': 33.36333,
# ...

# %%
#get stations in a zip code
base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data?"
token = ncdc

params = {
    'datasetid' : 'GSOM',
    'locationid' : 'FIPS:13',
    'units' : 'standard',
    'startdate' : '2019-01-01',
    'enddate' : '2019-12-01',
    'datatypeid' : 'TAVG', 
    'stationid': 'GHCND:USC00090236'
    # TAVG avg temp
    #'datatypeid' : 'PRCP', # percipitation
    #'datatypeid' : 'TSUN', # sun
    #AWND # average wind
    #TMAX # max temp
    #TMIN # min temp
    #SNOW # snowfall
    #'stationid' : 'GHCND:USC00090006'
}

#//www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GSOM&stationid=GHCND:USC00010008&units=standard&startdate=2010-05-01&enddate=2010-05-31


results = requests.get(base_url, params=params, headers={'token':token})

# %%
results.json()
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 12, 'limit': 25}},
#  'results': [{'date': '2019-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090236',
#    'attributes': ',7',
#    'value': 42.0},
#   {'date': '2019-02-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090236',
#    'attributes': ',7',
#    'value': 48.5},
#   {'date': '2019-03-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090236',
#    'attributes': ',7',
#    'value': 49.9},
#   {'date': '2019-04-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090236',
#    'attributes': ',7',
#    'value': 59.5},
#   {'date': '2019-05-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090236',
#    'attributes': ',7',
#    'value': 71.0},
#   {'date': '2019-06-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USC00090236',
#    'attributes': ',7',
#    'value': 73.1},
#   {'date': '2019-07-01T00:00:00',
# ...

# %%
base_url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/stations?"
token = ncdc

params = {
    'datasetid' : 'GSOM',
    #'datatypeid' : 'TAVG',
    'locationid' : 'FIPS:13',
    #'units' : 'standard',
    #'locationid' : 'ZIP:30062',
    'enddate' : '2010-12-01',
    'startdate' : '2000-01-01',
    'datatypeid' : 'TMAX'
}

#//www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GSOM&stationid=GHCND:USC00010008&units=standard&startdate=2010-05-01&enddate=2010-05-31


station_results = requests.get(base_url, params=params, headers={'token':token})

# %%
station_results.json()
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 195, 'limit': 25}},
#  'results': [{'elevation': 73.2,
#    'mindate': '1903-09-01',
#    'maxdate': '2011-02-01',
#    'latitude': 31.938,
#    'name': 'ABBEVILLE, GA US',
#    'datacoverage': 0.7489,
#    'id': 'GHCND:USC00090010',
#    'elevationUnit': 'METERS',
#    'longitude': -83.3077},
#   {'elevation': 70.1,
#    'mindate': '2001-07-01',
#    'maxdate': '2002-04-01',
#    'latitude': 31.13972,
#    'name': 'ADEL, GA US',
#    'datacoverage': 0.9011,
#    'id': 'GHCND:USC00090051',
#    'elevationUnit': 'METERS',
#    'longitude': -83.42306},
#   {'elevation': 54.9,
#    'mindate': '1892-07-01',
#    'maxdate': '2019-12-01',
#    'latitude': 31.5338,
#    'name': 'ALBANY 3 SE, GA US',
#    'datacoverage': 0.983,
#    'id': 'GHCND:USC00090140',
#    'elevationUnit': 'METERS',
#    'longitude': -84.1488},
#   {'elevation': 297.2,
#    'mindate': '1952-05-01',
#    'maxdate': '2019-12-01',
#    'latitude': 34.165,
# ...

# %%
weather_df = pd.read_csv('temperatures.csv')

# %%
weather_df
# Out:
#       Year  Month    State    TAVG
# 0     2000      1  Alabama  47.156
# 1     2000      2  Alabama  52.332
# 2     2000      3  Alabama  58.888
# 3     2000      4  Alabama  60.844
# 4     2000      5  Alabama  74.008
# ...    ...    ...      ...     ...
# 6727  2010      8  Wyoming  66.400
# 6728  2010      9  Wyoming  57.408
# 6729  2010     10  Wyoming  48.600
# 6730  2010     11  Wyoming  29.116
# 6731  2010     12  Wyoming  24.188
#
# [6732 rows x 4 columns]

# %%
for
